# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !unzip /content/drive/MyDrive/dataset.pcb.zip -d /content/
# Out:
# Archive:  /content/drive/MyDrive/dataset.pcb.zip
#    creating: /content/dataset/images/
#    creating: /content/dataset/images/train/
#   inflating: /content/dataset/images/train/01_missing_hole_01.jpg
#   inflating: /content/dataset/images/train/01_missing_hole_02.jpg
#   inflating: /content/dataset/images/train/01_missing_hole_03.jpg
#   inflating: /content/dataset/images/train/01_missing_hole_04.jpg
#   inflating: /content/dataset/images/train/01_missing_hole_05.jpg
#   inflating: /content/dataset/images/train/01_missing_hole_07.jpg
#   inflating: /content/dataset/images/train/01_missing_hole_09.jpg
#   inflating: /content/dataset/images/train/01_missing_hole_12.jpg
#   inflating: /content/dataset/images/train/01_missing_hole_14.jpg
#   inflating: /content/dataset/images/train/01_missing_hole_15.jpg
#   inflating: /content/dataset/images/train/01_missing_hole_16.jpg
#   inflating: /content/dataset/images/train/01_missing_hole_17.jpg
# ...

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16031, done.
# remote: Counting objects: 100% (64/64), done.
# remote: Compressing objects: 100% (39/39), done.
# remote: Total 16031 (delta 35), reused 40 (delta 25), pack-reused 15967
# Receiving objects: 100% (16031/16031), 14.69 MiB | 28.54 MiB/s, done.
# Resolving deltas: 100% (11001/11001), done.

# %%
# %cd yolov5
# Out:
# /content/yolov5

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 4.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.8/644.8 kB 9.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.5 MB/s eta 0:00:00
# ...

# %%
# !python train.py --img 416 --batch 16 --epochs 300 --data dataset1.yaml --weights yolov5s.pt --cache --name pcb_1st
# Out:
# 2023-10-30 07:06:18.793371: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-10-30 07:06:18.793431: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-10-30 07:06:18.793468: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !zip -r /content/drive/MyDrive/dataset.pcb.zip /content/yolov5/runs
# Out:
#   adding: content/yolov5/runs/ (stored 0%)
#   adding: content/yolov5/runs/train/ (stored 0%)
#   adding: content/yolov5/runs/train/pcb_1st/ (stored 0%)
#   adding: content/yolov5/runs/train/pcb_1st/train_batch0.jpg (deflated 3%)
#   adding: content/yolov5/runs/train/pcb_1st/train_batch1.jpg (deflated 4%)
#   adding: content/yolov5/runs/train/pcb_1st/val_batch0_pred.jpg (deflated 19%)
#   adding: content/yolov5/runs/train/pcb_1st/events.out.tfevents.1698649581.0700410ad3f6.3679.0 (deflated 31%)
#   adding: content/yolov5/runs/train/pcb_1st/results.png (deflated 7%)
#   adding: content/yolov5/runs/train/pcb_1st/labels.jpg (deflated 28%)
#   adding: content/yolov5/runs/train/pcb_1st/train_batch2.jpg (deflated 4%)
#   adding: content/yolov5/runs/train/pcb_1st/F1_curve.png (deflated 8%)
#   adding: content/yolov5/runs/train/pcb_1st/confusion_matrix.png (deflated 21%)
#   adding: content/yolov5/runs/train/pcb_1st/hyp.yaml (deflated 45%)
# ...

# %%
# !python val.py --weights runs/train/pcb_1st/weights/best.pt --data dataset1.yaml
# Out:
# val: data=dataset1.yaml, weights=['runs/train/pcb_1st/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-231-gc2f131a Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7026307 parameters, 0 gradients, 15.8 GFLOPs
# val: Scanning /content/dataset/labels/val.cache... 138 images, 0 backgrounds, 0 corrupt: 100% 138/138 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:23<00:00,  4.79s/it]
#                    all        138        598      0.938      0.882      0.937      0.479
#           missing_hole        138        100       0.97       0.98      0.976      0.549
# ...
